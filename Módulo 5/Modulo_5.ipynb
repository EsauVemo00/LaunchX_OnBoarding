# %% [markdown]
# # Módulo 5
# Usar operaciones matemáticas

# %% [markdown]
# ## Suma

# %%
answer=30+12
print(answer)
# Out:
# 42

# %% [markdown]
# ## Resta

# %%
difference=30-12
print(difference)
# Out:
# 18

# %% [markdown]
# ## Multiplicación

# %%
product=30*12
print(product)
# Out:
# 360

# %% [markdown]
# ## División

# %%
quotient=30/12
print(quotient)
# Out:
# 2.5

# %% [markdown]
# ### División de piso
# (Es un redondeo hacía abajo se utiliza la doble diagonal)

# %%
sec=1042
min=sec//60
print(min)
# Out:
# 17

# %% [markdown]
# ### Residuo
# Para este es con 5

# %%
sec=1042
min=sec//60
secs=1042%60
print(min)
print(secs)
# Out:
# 17
# 22

# %% [markdown]
# ## Jerarquía de operaciones

# %%
result_1=1032+26*2
result_2=1032+(26*2)
print(result_1,result_2)
# Out:
# 1084 1084

# %% [markdown]
# ## Convertir cadenas en número

# %%
demo_int=int('215')
print(demo_int)

demo_float=float('215.3')
print(demo_float)
# Out:
# 215
# 215.3

# %% [markdown]
# ## Valores absolutos

# %%
a=39-16
b=16-39
print(a,b)
print(abs(a),abs(b))
# Out:
# 23 -23
# 23 23

# %% [markdown]
# ## Redondeo

# %%
print(round(14.5))
# Out:
# 14

# %% [markdown]
# ### Biblioteca Math para redondeo
# utuliza las funciones (Ceil y floor)

# %%
from math import ceil, floor

round_up=ceil(12.5)
print(round_up)

round_down=floor(12.5)
print(round_down)
# Out:
# 13
# 12
